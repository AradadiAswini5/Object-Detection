# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/FruitDetection
# Out:
# bus.jpg  DatasetPrepare.ipynb  README.txt  test   Untitled.ipynb  yolov8n.pt
# cli.log  data.yaml	       runs	   train  valid		  yolov8s.pt

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/Colab Notebooks/FruitDetection/data.yaml",
    epochs=10,          # change to any number
    imgsz=640,
    batch=16,
    device=0           # GPU enabled
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3982514554.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov8n.pt")
#       4
#       5 model.train(
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/Colab Notebooks/FruitDetection/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16,
    device="cuda"      # Training on GPU
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cat "/content/drive/MyDrive/Colab Notebooks/FruitDetection/data.yaml"
# Out:
# train: /content/drive/MyDrive/Colab Notebooks/FruitDetection/train/images
# val: /content/drive/MyDrive/Colab Notebooks/FruitDetection/valid/images
# test: /content/drive/MyDrive/Colab Notebooks/FruitDetection/test/images
#
# names:
#   0: apple
#   1: banana
#   2: orange
#   3: pineapple
#   4: mango
#   5: other_fruit

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/Colab Notebooks/FruitDetection/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16,
    device=0     # GPU 🚀
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/FruitDetection" /content/FruitDetection

# %%
# !cat /content/FruitDetection/data.yaml
# Out:
# train: /content/drive/MyDrive/Colab Notebooks/FruitDetection/train/images
# val: /content/drive/MyDrive/Colab Notebooks/FruitDetection/valid/images
# test: /content/drive/MyDrive/Colab Notebooks/FruitDetection/test/images
#
# names:
#   0: apple
#   1: banana
#   2: orange
#   3: pineapple
#   4: mango
#   5: other_fruit

# %%
# !cat /content/FruitDetection/data.yaml
# Out:
# train: /content/FruitDetection/train/images
# val: /content/FruitDetection/valid/images
# test: /content/FruitDetection/test/images
#
# names:
#   0: apple
#   1: banana
#   2: orange
#   3: pineapple
#   4: mango
#   5: other_fruit

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/FruitDetection/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image("/content/runs/detect/train3/results.png")

# %%
model = YOLO("/content/runs/detect/train3/weights/best.pt")

results = model.predict("/content/FruitDetection/valid/images", save=True)
# Out:
# image 1/914 /content/FruitDetection/valid/images/002c29e02227cfdf_jpg.rf.bdeb29195e770f3b836b15a48a1bf829.jpg: 640x640 1 orange, 7.9ms
# image 2/914 /content/FruitDetection/valid/images/003e27dee1bb3bd6_jpg.rf.fcb1b29e2c6795a22364f32dbcc2ded0.jpg: 640x640 (no detections), 7.3ms
# image 3/914 /content/FruitDetection/valid/images/003f09b07cc748e4_jpg.rf.bc51e28215e368b3940c601a878fbc62.jpg: 640x640 2 bananas, 7.2ms
# image 4/914 /content/FruitDetection/valid/images/0048a9ad59d8ab79_jpg.rf.8a324bb752732a70e2bc846b44c96d19.jpg: 640x640 1 apple, 7.3ms
# image 5/914 /content/FruitDetection/valid/images/0055f7e5bac0c8e1_jpg.rf.7bb1d953a097322150e11573b6e58e65.jpg: 640x640 1 pineapple, 7.2ms
# image 6/914 /content/FruitDetection/valid/images/00881627629888f6_jpg.rf.181e36ac45e68172f957e1413ef1074e.jpg: 640x640 2 apples, 7.2ms
# image 7/914 /content/FruitDetection/valid/images/00c774bd893b8dda_jpg.rf.1447aae29e01cc2ef4bfbaafa85dcffc.jpg: 640x640 1 apple, 1 pineapple, 7.3ms
# ...

# %%
from google.colab import files
files.download("/content/runs/detect/train3/weights/best.pt")
